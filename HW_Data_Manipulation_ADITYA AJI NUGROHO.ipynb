# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('telco_customer_churn.csv')

# %%
#df.customerID.nunique()

df

#berdasarkan nunique jumlah customer berdasarkan customer ID adalah 7043 yg berarti tidak ada customer yg memiliki ID ganda
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %% [markdown]
# ### Welcome to Day 6 Homework. Please answer the questions below!

# %% [markdown]
# 1. Buanglah baris dengan `tenure` samadengan 0 (jadi, data yang akan kita analisa di PR ini adalah baris-baris dengan `tenure` TIDAK samadengan 0). Ada berapa baris yang sekarang tersedia di data kita?
#
# 2. Bagi customer yang ***TIDAK MEMILIKI PARTNER*** dan ***TIDAK MEMILIKI DEPENDENTS***, berapa ***rata-rata*** dari `tenure` mereka?
#
# 3. Bagi customer yang ***MEMILIKI PARTNER*** dan ***TIDAK MEMILIKI DEPENDENTS***, berapa maksimal `MonthlyCharges` yang tercata?
#
# 4. Berapa banyak customer yang ***TIDAK MEMILIKI PARTNER*** namun ***MEMILIKI DEPENDENTS***?
#
# 5. Berapa rata-rata ***TOTAL CHARGES*** dari customer ***NON-SENIOR CITIZEN*** (Senior Citizen = 0) yang memiliki ***PHONE SERVICE*** dan memiliki ***INTERNET SERVICE FIBER OPTIC***?

# %% [markdown]
# #### Silakan menuliskan kode untuk menjawab 5 pertanyaan di atas...

# %%
#soal 1

df_edit = df.copy()

con_1 = df_edit['tenure'] == 0
con_2 = df_edit['tenure'] != 0 #bisa juga menggunakan >0

#df[con_1] #untuk melihat column masing-masing tenure
#df[con_2]

df_edit = df_edit[con_2]
df_edit

#df_edit.info()

#dari 7043 data tersisa menjadi 7032 data yg berarti tenure yg memiliki nilai 0 berjumlah 11
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
#soal 2

con_part_1 = df_edit['Partner'] == 'No'
con_dept_1 = df_edit['Dependents'] == 'No'
con_ten = df_edit['tenure']

filtered_df = df_edit[con_part_1 & con_dept_1 & con_ten]

tabel_baru_1 =  filtered_df[['Partner', 'Dependents', 'tenure']] 

#tabel_baru_1

tabel_baru_1['tenure'].mean()
# Out:
# 20.374376039933445

# %%
#soal 3

con_part_2 = df_edit['Partner'] == 'Yes'
con_MonthPay = df_edit['MonthlyCharges']

new_con_df = df_edit[con_part_2 & con_dept_1 & con_MonthPay]

tabel_baru_2 = new_con_df[['Partner', 'Dependents', 'MonthlyCharges']]
#tabel_baru_2

#tabel_baru_2.applymap(np.isreal)

tabel_baru_2['MonthlyCharges'].max()
# Out:
# 118.6

# %%
#soal 4

con_dept_2 = df_edit['Dependents'] == 'Yes'

aselole = df_edit[con_part_1 & con_dept_2]

tabel_baru_3 = aselole[['Partner', 'Dependents']]
tabel_baru_3.reset_index(drop=True, inplace=True)
#tabel_baru_3

len(tabel_baru_3)
#jumlahnya 359
# Out:
# 359

# %%
#soal 5

con_total = df_edit['TotalCharges']
con_senior = df_edit['SeniorCitizen'] == 0
con_phone = df_edit['PhoneService'] == 'Yes' 
con_Internet = df_edit['InternetService'] == 'Fiber optic'


final_Q = df_edit[con_senior & con_phone & con_Internet & con_total].copy() #int(con_total) harus diakhir kalau ingin menghindari error

final_Q[['SeniorCitizen', 'PhoneService', 'InternetService', 'TotalCharges']]
final_Q


#final_Q['TotalCharges'] = pd.to_numeric(final_Q['TotalCharges'], errors='coerce') #mengubah str number menjadi numeric number


#tabel_final.applymap(np.isreal) #mengecek data total charges apakah ada yg string atau tidak



#mean_tabel_final = final_Q['TotalCharges'].mean()
#print('rata rata total charges:', mean_tabel_final)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 4     9237-HQITU  Female              0      No         No       2
# 5     9305-CDSKC  Female              0      No         No       8
# 6     1452-KIOVK    Male              0      No        Yes      22
# 8     7892-POOKP  Female              0     Yes         No      28
# 12    8091-TTVAX    Male              0     Yes         No      58
# ...          ...     ...            ...     ...        ...     ...
# 7033  9767-FFLEM    Male              0      No         No      38
# 7034  0639-TSIQW  Female              0      No         No      67
# 7035  8456-QDAVC    Male              0      No         No      19
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 4             Yes            No     Fiber optic             No  ...
# ...

# %% [markdown]
# ### Silakan menjawab di bawah ini:

# %% [markdown]
# #### Soal 1:
# Buanglah baris dengan tenure samadengan 0 (jadi, data yang akan kita analisa di PR ini adalah baris-baris dengan tenure TIDAK samadengan 0). Ada berapa baris yang sekarang tersedia di data kita?
#
# #### Jawaban: 7032 (langsung edit di sini aja)

# %% [markdown]
# #### Soal 2:
# Bagi customer yang TIDAK MEMILIKI PARTNER dan TIDAK MEMILIKI DEPENDENTS, berapa rata-rata dari tenure mereka?
#
# #### Jawaban: 20.374376039933445

# %% [markdown]
# #### Soal 3:
# Bagi customer yang MEMILIKI PARTNER dan TIDAK MEMILIKI DEPENDENTS, berapa maksimal MonthlyCharges yang tercata?
#
# #### Jawaban: 118.6

# %% [markdown]
# #### Soal 4:
# Berapa banyak customer yang TIDAK MEMILIKI PARTNER namun MEMILIKI DEPENDENTS?
#
# #### Jawaban: 359

# %% [markdown]
# #### Soal 5:
# Berapa rata-rata TOTAL CHARGES dari customer NON-SENIOR CITIZEN (Senior Citizen = 0) yang memiliki PHONE SERVICE dan memiliki INTERNET SERVICE FIBER OPTIC?
#
# #### Jawaban: 3226.4927373068435
